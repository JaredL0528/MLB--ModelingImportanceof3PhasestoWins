# %%
#allow output from every line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
from pybaseball import lahman
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time

# %%
project_data = pd.read_csv("SAL384FinalData.csv")

# %%
project_data_matrix = project_data[['W-L%', 'R/G', 'OPS', 'RA/G', 'ERA+', 'FIP','DefEff']]
sns.pairplot(project_data_matrix, diag_kind = "kde", kind = "reg", plot_kws = {'line_kws':{'color':'orange'}, 'scatter_kws':{'alpha':0.2}}).savefig("scatter_matrix.png")
# Out:
# <img src="data:image/png;base64,..." width="1968">

# %%
sns.catplot(x = 'R/G', y = 'Team', kind = 'box', data = project_data).savefig("batting_boxplot.png")
# Out:
# <img src="data:image/png;base64,..." width="561.7777777777778">

# %%
sns.catplot(x = 'RA/G', y = 'Team', kind = 'box', data = project_data).savefig("pitching_boxplot.png")
# Out:
# <img src="data:image/png;base64,..." width="499.55555555555554">

# %%
sns.catplot(x = 'DefEff', y = 'Team', kind = 'box', data = project_data).savefig("fielding_boxplot.png")
# Out:
# <img src="data:image/png;base64,..." width="561.7777777777778">
